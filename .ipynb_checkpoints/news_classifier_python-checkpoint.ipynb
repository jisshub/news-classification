# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import nltk
# from nltk.tokenize import sent_tokenize
# from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
STOPWORDS = set(stopwords.words('english'))

# %%
# !git clone https://github.com/jisshub/datasets_repo.git
news_df = pd.read_json('datasets_repo/News_Category_Dataset.json', lines=True)
news_df.head()
# Out:
#            authors       category       date  \
# 0  Melissa Jeltsen          CRIME 2018-05-26
# 1    Andy McDonald  ENTERTAINMENT 2018-05-26
# 2       Ron Dicker  ENTERTAINMENT 2018-05-26
# 3       Ron Dicker  ENTERTAINMENT 2018-05-26
# 4       Ron Dicker  ENTERTAINMENT 2018-05-26
#
#                                             headline  \
# 0  There Were 2 Mass Shootings In Texas Last Week...
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2    Hugh Grant Marries For The First Time At Age 57
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  Julianna Margulies Uses Donald Trump Poop Bags...
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/texas-ama...
# 1  https://www.huffingtonpost.com/entry/will-smit...
# 2  https://www.huffingtonpost.com/entry/hugh-gran...
# 3  https://www.huffingtonpost.com/entry/jim-carre...
# 4  https://www.huffingtonpost.com/entry/julianna-...
#
#                                    short_description
# 0  She left her husband. He killed their children...
# 1                           Of course it has a song.
# 2  The actor and his longtime girlfriend Anna Ebe...
# 3  The actor gives Dems an ass-kicking for not fi...
# 4  The "Dietland" actress said using the bags is ...

# %%
# print unique categories
print(news_df.category.unique())
# Out:
# ['CRIME' 'ENTERTAINMENT' 'WORLD NEWS' 'IMPACT' 'POLITICS' 'WEIRD NEWS'
#  'BLACK VOICES' 'WOMEN' 'COMEDY' 'QUEER VOICES' 'SPORTS' 'BUSINESS'
#  'TRAVEL' 'MEDIA' 'TECH' 'RELIGION' 'SCIENCE' 'LATINO VOICES' 'EDUCATION'
#  'COLLEGE' 'PARENTS' 'ARTS & CULTURE' 'STYLE' 'GREEN' 'TASTE'
#  'HEALTHY LIVING' 'THE WORLDPOST' 'GOOD NEWS' 'WORLDPOST' 'FIFTY' 'ARTS']

# %%
# combining some raw data categories that are very close
news_df.category = news_df.category.map(
    lambda x: "WORLD" if x == "WORLDPOST" or x == "THE WORLDPOST" or x == 'WORLD NEWS' else x)
news_df.category = news_df.category.map(
    lambda y: "ARTS & CULTURE" if y == "ARTS" or y == "ARTS & CULTURE" else y)
news_df.category = news_df.category.map(
    lambda z: "EDUCATION" if z == "EDUCATION" or z == "COLLEGE" else z)
news_df.category = news_df.category.map(
    lambda d: "HEALTH" if d == "HEALTHY LIVING" else d)

# removing rows with description size less than 10
mask = news_df['short_description'].str.len() > 20
news_df = news_df.loc[mask]
# combines headline and short_description for the input
news_df['text'] = news_df.headline+" "+news_df.short_description
# replace empty values with NaN
news_df = news_df.replace("", np.NaN)
# drop rows with value as NaN
news_df.dropna(axis=0, inplace=True)

# news_df.head()

# %%
# removing symbols, unwanted characters, stopwords from text and lemmatizing each words in the text.
import re
symbols_dt = re.compile('[/(){}\[\]\|@,;]')
symbols_dt2 = re.compile('[^0-9a-z +_]')
STOPWORDS = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()


def clean_text(text):
    text = text.lower()
    text = symbols_dt.sub(' ', text)  # remove symbols in text data
    text = symbols_dt2.sub('', text)
    # delete stopwords from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    text = ' '.join([lemmatizer.lemmatize(w) for w in text.split()])
    return text


news_df['text'] = news_df['text'].apply(clean_text)
news_df['text'] = news_df['text'].str.replace('\d+', '')
# len(news_df['text'])

# %%
# here v represents each category as an integer in the category_id column.
from io import StringIO
col = ['category', 'text']
# news_df = news_df.reindex(columns=col)


news_df = news_df[col]
news_df = news_df[pd.notnull(news_df['text'])]

news_df.columns = ['category', 'text']
news_df['category_id'] = news_df['category'].factorize()[0]
category_id_df = news_df[['category', 'category_id']
                         ].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'category']].values)
# print(category_to_id)
news_df.head()
# Out:
#         category                                               text  \
# 0          CRIME   mass shooting texas last week  tv left husban...
# 1  ENTERTAINMENT  smith join diplo nicky jam  world cup official...
# 2  ENTERTAINMENT  hugh grant marries first time age  actor longt...
# 3  ENTERTAINMENT  jim carrey blast castrato adam schiff democrat...
# 4  ENTERTAINMENT  julianna margulies us donald trump poop bag pi...
#
#    category_id
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
# set category column as an index
news_df = news_df.set_index("category")
news_df
# Out:
#                                                              text  category_id
# category
# CRIME            mass shooting texas last week  tv left husban...            0
# ENTERTAINMENT   smith join diplo nicky jam  world cup official...            1
# ENTERTAINMENT   hugh grant marries first time age  actor longt...            1
# ENTERTAINMENT   jim carrey blast castrato adam schiff democrat...            1
# ENTERTAINMENT   julianna margulies us donald trump poop bag pi...            1
# ENTERTAINMENT   morgan freeman devastated sexual harassment cl...            1
# ENTERTAINMENT   donald trump lovin new mcdonalds jingle tonigh...            1
# ENTERTAINMENT   watch amazon prime thats new week there great ...            1
# ENTERTAINMENT   mike myers reveals hed like fourth austin powe...            1
# ENTERTAINMENT   watch hulu thats new week youre getting recent...            1
# ENTERTAINMENT   justin timberlake visit texas school shooting ...            1
# IMPACT          way life risk remote oystergrowing region call...            2
# POLITICS        trump crackdown immigrant parent put kid alrea...            3
# POLITICS        trump son concerned fbi obtained wiretap putin...            3
# POLITICS        edward snowden there one trump love vladimir p...            3
# POLITICS        booyah obama photographer hilariously troll tr...            3
# POLITICS        ireland vote repeal abortion amendment landsli...            3
# POLITICS        ryan zinke look reel back critic grand pivot c...            3
# POLITICS        trump scottish golf resort pay woman significa...            3
# WEIRD NEWS      weird father day gift dad doesnt know want buy...            4
# ENTERTAINMENT   twitter putstarwarsinotherfilms universally en...            1
# WEIRD NEWS      mystery wolflike animal reportedly shot montan...            4
# WORLD           north korea still open talk trump cancel summi...            5
# WORLD           thousand travel home ireland vote abortion acc...            5
# BLACK VOICES    warrior coach steve kerr call nfl ban protest ...            6
# BLACK VOICES    historic victory barbados elect first female p...            6
# BLACK VOICES    police killed least  black american moment col...            6
# POLITICS        jack johnson pardoned taboo sex still criminal...            3
# BLACK VOICES    bet chairman ceo debra lee stepping lee brough...            6
# CRIME           rachel dolezal face felony charge welfare frau...            0
# ...                                                           ...          ...
# IMPACT          four way mindfulness make successful entrepren...            2
# RELIGION        spiritual greek easter throughout holy week or...           15
# TASTE           margarita fanatic weve got swag jimmy buffet m...           23
# RELIGION        often untold story easter holy saturday day he...           15
# GREEN           throwing away good water folk even guy pissing...           22
# ENTERTAINMENT   still category missing academy award besides g...            1
# QUEER VOICES    turbo taxing last gay nerve marriage need qual...            9
# ENTERTAINMENT   zakis review transcendence transcendence look ...            1
# WORLD           men must play part battle arab woman right cul...            5
# GREEN           way life risk anniversary bp oil spill april  ...           22
# HEALTH          loving narcissist without losing difficult peo...           24
# IMPACT          diagnosed bipolar disorder youve got youve got...            2
# RELIGION        jesus message death life holy week interpreted...           15
# WOMEN           power purse untapped opportunity woman wield b...            7
# ARTS & CULTURE  artist statement cant live cant live without a...           20
# IMPACT          activist sometimes feel like im spinning hamst...            2
# ENTERTAINMENT   grey anatomyrecap yang loses go alone mentione...            1
# TASTE           easter cheese crescia collected recipe scrap f...           23
# EDUCATION       son read one book middle school great reading ...           18
# PARENTS         parenting expert breaking hard really uncomfor...           19
# WOMEN           complicated learned fend question always remem...            7
# WORLD           adios gabo friend dy left deep pain multitude ...            5
# POLITICS        chris christie president apparently thats way ...            3
# PARENTS         toddler taught still toddler known place happy...           19
# IMPACT          making safety net smarter everyday million ame...            2
# ARTS & CULTURE  aisle view kiss vampire comedic chameleon arni...           20
# POLITICS        gop old ploy tag president obama race baiter b...            3
# POLITICS        dear president obama im assuming aware issue p...            3
# TASTE           five tip cooking one often hear people describ...           23
# HEALTH          reason happy thought feeling powerful many bas...           24
#
# [91128 rows x 2 columns]

# %%
news_df = news_df.drop(['IMPACT', 'QUEER VOICES', 'LATINO VOICES', 'BLACK VOICES', 'FIFTY',
                        'WEIRD NEWS', 'ENTERTAINMENT', 'GREEN', 'GOOD NEWS', 'COMEDY', 'PARENTS', 'WOMEN',
                        'POLITICS', 'MEDIA'], axis=0)
news_df = news_df.replace("", np.NaN)
# drop rows with value as NaN
news_df.dropna(axis=0, inplace=True)

# %%
# reset the index, thus categry is added as a column and set a new index.
news_df = news_df.reset_index("category")
news_df
# Out:
#              category                                               text  \
# 0               CRIME   mass shooting texas last week  tv left husban...
# 1               WORLD  north korea still open talk trump cancel summi...
# 2               WORLD  thousand travel home ireland vote abortion acc...
# 3               CRIME  rachel dolezal face felony charge welfare frau...
# 4               CRIME  man face charge pulling knife stun gun muslim ...
# 5               CRIME   people injured indiana school shooting male s...
# 6               WORLD  trump suggests north korea summit could still ...
# 7               WORLD  north korea threatens call trump summit warns ...
# 8               WORLD  investigation find russian missile shot flight...
# 9               WORLD  kim jong un baited trump canceling north korea...
# 10             SPORTS  jet chairman christopher johnson wont fine pla...
# 11           BUSINESS  u launch auto import probe china vow defend in...
# 12             SPORTS  trump posthumously pardon boxer jack johnson p...
# 13              WORLD  south korea responds trump sudden cancellation...
# 14             TRAVEL   way make family road trip easier parent whove...
# 15             SPORTS  anna kournikova dancing bouncing baby cutest t...
# 16             SPORTS  trump say nfl player unwilling stand anthem ma...
# 17               TECH  facebook accused reading text accessing microp...
# 18               TECH  selfdriving uber fatal accident  second react ...
# 19              WORLD  trump american far right stoke hate canada hat...
# 20              WORLD  farright antiestablishment party set form ital...
# 21           RELIGION  southern baptist leader said abused woman pray...
# 22             SPORTS  brandi chastain totally agrees hall fame plaqu...
# 23              WORLD  survivor rwandan genocide country first female...
# 24              CRIME  maryland police charge  church leader past abu...
# 25             SPORTS  nfl ban kneeling national anthem team set poli...
# 26             TRAVEL   trip take new york city long weekend charming...
# 27             TRAVEL  disney reveals opening season star war theme p...
# 28              WORLD  australian archbishop convicted covering child...
# 29              WORLD  mark zuckerberg extends facebook apology tour ...
# ...               ...                                                ...
# 29609  ARTS & CULTURE  next normal cal rep moment bristle energy coil...
# 29610           WORLD  justice possible north korea victim torture ra...
# 29611        BUSINESS  progressive think twice embracing uber lyft st...
# 29612        RELIGION  behind every easter crucifixion easter mean an...
# 29613  ARTS & CULTURE  mark innerst dc moore gallery recently spoke m...
# 29614          SPORTS  nba eastern conference playoff preview pacer r...
# 29615        RELIGION  resurrection jesus million people part world c...
# 29616  ARTS & CULTURE  boy attic two recent bay area production inclu...
# 29617        RELIGION  resurrection hope never needed saturday face s...
# 29618         SCIENCE  psychiatry personal last week went presentatio...
# 29619          HEALTH  need bouncer bartender live happy healthy life...
# 29620          HEALTH  video game improve dialogue mental illness str...
# 29621           WORLD  assad friend brag winning obama administration...
# 29622           CRIME  david chronicle rubin carter fight free david ...
# 29623           TASTE  answer every question youve never asked marshm...
# 29624        RELIGION  pope asks forgiveness one legitimately speak p...
# 29625          HEALTH  wakeup call inspired change overdrive sleep de...
# 29626        RELIGION  spiritual greek easter throughout holy week or...
# 29627           TASTE  margarita fanatic weve got swag jimmy buffet m...
# 29628        RELIGION  often untold story easter holy saturday day he...
# 29629           WORLD  men must play part battle arab woman right cul...
# 29630          HEALTH  loving narcissist without losing difficult peo...
# 29631        RELIGION  jesus message death life holy week interpreted...
# 29632  ARTS & CULTURE  artist statement cant live cant live without a...
# 29633           TASTE  easter cheese crescia collected recipe scrap f...
# 29634       EDUCATION  son read one book middle school great reading ...
# 29635           WORLD  adios gabo friend dy left deep pain multitude ...
# 29636  ARTS & CULTURE  aisle view kiss vampire comedic chameleon arni...
# 29637           TASTE  five tip cooking one often hear people describ...
# 29638          HEALTH  reason happy thought feeling powerful many bas...
#
#        category_id
# 0                0
# 1                5
# 2                5
# 3                0
# 4                0
# 5                0
# 6                5
# 7                5
# 8                5
# 9                5
# 10              10
# 11              11
# 12              10
# 13               5
# 14              12
# 15              10
# 16              10
# 17              14
# 18              14
# 19               5
# 20               5
# 21              15
# 22              10
# 23               5
# 24               0
# 25              10
# 26              12
# 27              12
# 28               5
# 29               5
# ...            ...
# 29609           20
# 29610            5
# 29611           11
# 29612           15
# 29613           20
# 29614           10
# 29615           15
# 29616           20
# 29617           15
# 29618           17
# 29619           24
# 29620           24
# 29621            5
# 29622            0
# 29623           23
# 29624           15
# 29625           24
# 29626           15
# 29627           23
# 29628           15
# 29629            5
# 29630           24
# 29631           15
# 29632           20
# 29633           23
# 29634           18
# 29635            5
# 29636           20
# 29637           23
# 29638           24
#
# [29639 rows x 3 columns]

# %%
# ploting each category and corresponding no of samples - bar chart
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 6))
news_df.groupby('category').text.count().plot.bar(ylim=0)
plt.show()

# %%
# to get the info about our preprocessed news dataframe
news_df.category.value_counts()
# Out:
# WORLD             5230
# HEALTH            4941
# BUSINESS          3059
# SPORTS            2891
# ARTS & CULTURE    2117
# RELIGION          1738
# TASTE             1735
# EDUCATION         1731
# CRIME             1643
# TRAVEL            1555
# STYLE             1221
# TECH               899
# SCIENCE            879
# Name: category, dtype: int64

# %% [markdown]
# each text data as feature vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
d = news_df["text"].__iter__()
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        norm='l2', encoding='latin-1', ngram_range=(1, 2))
features = tfidf.fit_transform(d)
labels = news_df.category_id
features.shape
# Out:
# (29639, 16530)

# %%
category_id_df = news_df[['category', 'category_id']
                         ].sort_values('category_id')
category_to_id = dict(category_id_df.values)
print(category_to_id)
# Out:
# {'CRIME': 0, 'WORLD': 5, 'SPORTS': 10, 'BUSINESS': 11, 'TRAVEL': 12, 'TECH': 14, 'RELIGION': 15, 'SCIENCE': 17, 'EDUCATION': 18, 'ARTS & CULTURE': 20, 'STYLE': 21, 'TASTE': 23, 'HEALTH': 24}

# %% [markdown]
#  find the terms that are the most correlated with each of the category:

# %%
from sklearn.feature_selection import chi2
N = 2
for category, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]

    print(f"{category}")
    nwline = '\n. '
    print(f"correlated unigrams:{nwline}{nwline.join(unigrams[-N:])}")
    print(f"correlated bigrams:{nwline}{nwline.join(bigrams[-N:])}")
# Out:
# ARTS & CULTURE
# correlated unigrams:
# . artist
# . art
# correlated bigrams:
# . stage door
# . first nighter
# BUSINESS
# correlated unigrams:
# . company
# . business
# correlated bigrams:
# . business qa
# . woman business
# CRIME
# correlated unigrams:
# . cop
# . police
# correlated bigrams:
# . police said
# . police say
# EDUCATION
# correlated unigrams:
# . college
# . student
# correlated bigrams:
# . college student
# . higher education
# HEALTH
# correlated unigrams:
# . cancer
# . health
# correlated bigrams:
# . mental health
# . gps guide
# RELIGION
# correlated unigrams:
# . pope
# . christian
# correlated bigrams:
# . meditation prayer
# . daily meditation
# SCIENCE
# correlated unigrams:
# . nasa
# . scientist
# correlated bigrams:
# . scientist say
# . solar system
# SPORTS
# correlated unigrams:
# . player
# . nfl
# correlated bigrams:
# . lebron james
# . super bowl
# STYLE
# correlated unigrams:
# . hair
# . fashion
# correlated bigrams:
# . red carpet
# . fashion week
# TASTE
# correlated unigrams:
# . delicious
# . recipe
# correlated bigrams:
# . ice cream
# . cooking cuff
# TECH
# correlated unigrams:
# . facebook
# . apple
# correlated bigrams:
# . social network
# . new iphone
# TRAVEL
# correlated unigrams:
# . traveler
# . travel
# correlated bigrams:
# . national park
# . looney front
# WORLD
# correlated unigrams:
# . syria
# . korea
# correlated bigrams:
# . prime minister
# . north korea

# %%
# train the classifier
# Naive Bayes Classifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(news_df['text'],
                                                    news_df['category'], random_state=0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)
# print(clf)

# %% [markdown]
# **Make Predictions**

# %%
print(clf.predict(count_vect.transform([
    "Instagram updating content-banning policies on app"
])))
# Out:
# ['TECH']

# %%
print(clf.predict(count_vect.transform([
    "Climate change poses mental health risks to children and teens"
])))
# Out:
# ['HEALTH']

# %%
print(clf.predict(count_vect.transform([
    "NASA scientist defends use of NUCLEAR weapons on asteroid"
])))
# Out:
# ['SCIENCE']

# %%
print(clf.predict(count_vect.transform([
    """A ‘Haunted’ Hotel in Colorado Is Reopening With an Even Creepier Vibe  
    """
]
)))
# Out:
# ['TRAVEL']

# %%
print(clf.predict(count_vect.transform([

    "Champions League Final: Gary Lineker backs Liverpool to beat Tottenham in Madrid"

])))
# Out:
# ['SPORTS']

# %%
print(clf.predict(count_vect.transform([

    "For many Muslims, Ramadan is a built-in digital detox program"

])))
# Out:
# ['WORLD']

# %% [markdown]
# **Model** **Selection**
#
# test various models and select model with more accuracy

# %% [markdown]
# *  Logistic Regression
#
# *  Multinomial Naive Bayes
#
# *  Linear SVC
#
# *  Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(
        model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df,
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# /home/jiss/python-projects/news_category_classifier/news_env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/jiss/python-projects/news_category_classifier/news_env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.721448
# LogisticRegression        0.709604
# MultinomialNB             0.602447
# RandomForestClassifier    0.232229
# Name: accuracy, dtype: float64

# %%
from sklearn.svm import LinearSVC
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(
    features, labels, news_df.index, test_size=0.33, random_state=0
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# print(y_pred)

# %%
# ploting confusion matrix

# from sklearn.metrics import confusion_matrix
# conf_mat = confusion_matrix(y_test, y_pred)
# fig, ax = plt.subplots(figsize=(10,10))
# sns.heatmap(conf_mat, annot=True, fmt='d',
#             xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.show()

# %%
# print the classification report for each class and the accuracy score
from sklearn import metrics
from sklearn.metrics import accuracy_score
print(metrics.classification_report(y_test, y_pred,
                                    target_names=news_df['category'].unique()))
print('accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
#                 precision    recall  f1-score   support
#
#          CRIME       0.77      0.76      0.76       547
#          WORLD       0.80      0.83      0.81      1701
#         SPORTS       0.83      0.85      0.84       961
#       BUSINESS       0.67      0.68      0.68       981
#         TRAVEL       0.69      0.69      0.69       495
#           TECH       0.67      0.48      0.56       307
#       RELIGION       0.73      0.66      0.69       570
#        SCIENCE       0.66      0.47      0.55       286
#      EDUCATION       0.78      0.70      0.74       589
# ARTS & CULTURE       0.72      0.72      0.72       695
#          STYLE       0.72      0.67      0.70       405
#          TASTE       0.74      0.78      0.76       555
#         HEALTH       0.72      0.80      0.76      1689
#
#      micro avg       0.74      0.74      0.74      9781
#      macro avg       0.73      0.70      0.71      9781
#   weighted avg       0.74      0.74      0.74      9781
#
# accuracy 0.7437889786320417
